# %% [markdown]
# ## Pandas part 2

# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\HP\Downloads\139e6cf1dafa0b8cb5ae32f6facef8a4-6bf4a1baf7a9245cf2f0b16feefa86672bf39b19\139e6cf1dafa0b8cb5ae32f6facef8a4-6bf4a1baf7a9245cf2f0b16feefa86672bf39b19\free-taxonomy.csv")

# %%
df1
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df1.dropna() ##temporaary change
df1
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df1.dropna(axis=1, inplace=True)

# %%
df1
# Out:
#                         name     id                         vocabulary
# 0                  Emergency   1101    Open Eligibility Human Services
# 1                       Food   1102    Open Eligibility Human Services
# 2                    Housing   1103    Open Eligibility Human Services
# 3                      Goods   1104    Open Eligibility Human Services
# 4                    Transit   1105    Open Eligibility Human Services
# ..                       ...    ...                                ...
# 322                In Danger  20089  Open Eligibility Human Situations
# 323          Chronic Illness  20090  Open Eligibility Human Situations
# 324                  Spouses  20091  Open Eligibility Human Situations
# 325               Dependents  20092  Open Eligibility Human Situations
# 326  Intellectual Disability  20093  Open Eligibility Human Situations
#
# [327 rows x 3 columns]

# %%
df1.dropna()
# Out:
#                         name     id                         vocabulary
# 0                  Emergency   1101    Open Eligibility Human Services
# 1                       Food   1102    Open Eligibility Human Services
# 2                    Housing   1103    Open Eligibility Human Services
# 3                      Goods   1104    Open Eligibility Human Services
# 4                    Transit   1105    Open Eligibility Human Services
# ..                       ...    ...                                ...
# 322                In Danger  20089  Open Eligibility Human Situations
# 323          Chronic Illness  20090  Open Eligibility Human Situations
# 324                  Spouses  20091  Open Eligibility Human Situations
# 325               Dependents  20092  Open Eligibility Human Situations
# 326  Intellectual Disability  20093  Open Eligibility Human Situations
#
# [327 rows x 3 columns]

# %%
df2 = pd.read_csv(r"C:\Users\HP\Downloads\139e6cf1dafa0b8cb5ae32f6facef8a4-6bf4a1baf7a9245cf2f0b16feefa86672bf39b19\139e6cf1dafa0b8cb5ae32f6facef8a4-6bf4a1baf7a9245cf2f0b16feefa86672bf39b19\free-taxonomy.csv")

# %%
df2.fillna("Bhumi")
# Out:
#                         name     id parent_name parent_id  \
# 0                  Emergency   1101           0       0.0
# 1                       Food   1102           0       0.0
# 2                    Housing   1103           0       0.0
# 3                      Goods   1104           0       0.0
# 4                    Transit   1105           0       0.0
# ..                       ...    ...         ...       ...
# 322                In Danger  20089     Urgency   20087.0
# 323          Chronic Illness  20090      Health    1106.0
# 324                  Spouses  20091        Role   20072.0
# 325               Dependents  20092        Role   20072.0
# 326  Intellectual Disability  20093  Disability   20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df2 = df2.astype(str)
df2.fillna("Bhumi", inplace=True)

# %%
df2
# Out:
#                         name     id parent_name parent_id  \
# 0                  Emergency   1101           0       0.0
# 1                       Food   1102           0       0.0
# 2                    Housing   1103           0       0.0
# 3                      Goods   1104           0       0.0
# 4                    Transit   1105           0       0.0
# ..                       ...    ...         ...       ...
# 322                In Danger  20089     Urgency   20087.0
# 323          Chronic Illness  20090      Health    1106.0
# 324                  Spouses  20091        Role   20072.0
# 325               Dependents  20092        Role   20072.0
# 326  Intellectual Disability  20093  Disability   20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           327 non-null    object
#  1   id             327 non-null    object
#  2   parent_name    327 non-null    object
#  3   parent_id      327 non-null    object
#  4   vocabulary     327 non-null    object
#  5   x-description  327 non-null    object
#  6   x-notes        327 non-null    object
#  7   services       327 non-null    object
# dtypes: object(8)
# memory usage: 20.6+ KB

# %%
df2.describe()
# Out:
#              name     id parent_name parent_id  \
# count         327    327         327       327
# unique        321    327          77        79
# top     Insurance  20093       Bhumi     Bhumi
# freq            2      1          22        22
#
#                              vocabulary x-description x-notes services
# count                               327           327     327      327
# unique                                2           227       2        1
# top     Open Eligibility Human Services         Bhumi   Bhumi    Bhumi
# freq                                233           100     276      327

# %% [markdown]
# ## broadcasting

# %%
df2["id"]=df2["id"]+"5000"

# %%
df2
# Out:
#                         name         id parent_name parent_id  \
# 0                  Emergency   11015000           0       0.0
# 1                       Food   11025000           0       0.0
# 2                    Housing   11035000           0       0.0
# 3                      Goods   11045000           0       0.0
# 4                    Transit   11055000           0       0.0
# ..                       ...        ...         ...       ...
# 322                In Danger  200895000     Urgency   20087.0
# 323          Chronic Illness  200905000      Health    1106.0
# 324                  Spouses  200915000        Role   20072.0
# 325               Dependents  200925000        Role   20072.0
# 326  Intellectual Disability  200935000  Disability   20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# ...
